# %%
#http://benalexkeen.com/k-means-clustering-in-python/

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(200)
k=3

df = pd.DataFrame({
    'x': [12, 20, 28, 18, 29, 33, 24, 45, 45, 52, 51, 52, 55, 53, 55, 61, 64, 69, 72],
    'y': [39, 36, 30, 52, 54, 46, 55, 59, 63, 70, 66, 63, 58, 23, 14, 8, 19, 7, 24]
})

df.shape
n=len(df)
m = len(data[0])
epsilon = 0.1
# Out:
# (19, 2)

# %%
#methods
def sim(x, y):
    if len(x) != len(y): raise Exception('Error ...')
    return math.sqrt(sum((a-b)**2 for a, b in zip(x,y) ))


def iplot(df, centroid):
    fig = plt.figure(figsize=(5, 5));
    plt.scatter(df['x'], df['y'], color='k');
    colmap = ['r','g','b']
    for i in range(len(centroid)):
#         print(centroid[i])
        plt.scatter(*centroid[i], color=colmap[i]);
    plt.xlim(0, 80);
    plt.ylim(0, 80);
    plt.show();

# %%
##init points
df_max_list = df.max().tolist()
df_min_list = df.min().tolist()
init_points = [[np.random.randint(l,u) for l, u in zip(df_min_list, df_max_list)] for _ in range(k)]
centroid = init_points

##compute dis
# -- init para
data = df.values
group = [[] for _ in range(k)]
dis_by_c = np.array([ (np.array([0]*m), 0) for _ in range(k)])

iplot()
# Out:
# [[38, 48], [28, 11], [54, 62]]

# %%
for _ in range(50):
    group = [[] for _ in range(k)]

    for j, l in enumerate(data):
        min_c = float('inf')
        min_dis= float('inf')
        for i, c in enumerate(centroid):
            dis = sim(l, c)
            if dis < min_dis:
                min_c=i
                min_dis = dis
    #             print(j, i, dis, min_dis, min_c)
        dis_by_c[min_c][0] += l
        dis_by_c[min_c][1] += 1
        group[min_c] += [j]

    #         print(dis_by_c)
    #         print(group)

    #     dis_by_c

    ##update centroid
    new_centroid = np.array([ x/y if y!=0 else x for x,y in dis_by_c ])
    move = sum([sim(new,old) for new, old in zip(new_centroid, centroid)])
    print(move)
    if move < epsilon: break
    centroid=new_centroid
#     print(centroid)
#     print(group)
    iplot()
# Out:
# 41.118097088816924
# 6.872543882030206
# 2.290847960676734
# 1.1454239803383728
# 0.68725438820302
# 0.45816959213535335
# 0.32726399438238407
# 0.24544799578679158
# 0.19090399672306532
# 0.15272319737845017
# 0.12495534330963612
# 0.10412945275803477
# 0.08810953694910278

# %%
#methods

#parameters

##ini centroid

#loop until reach cutoff

##compute dis

##update centroid
